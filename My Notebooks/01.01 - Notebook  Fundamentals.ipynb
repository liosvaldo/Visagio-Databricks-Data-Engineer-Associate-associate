# %%
print("hello databricks")

# %%
# %sql
SELECT "Hello From SQL in databricks"

# %% [markdown]
# # Title 1
# # Title 2

# %%
# %run ./Includes/Notebook

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
display(dbutils.fs.ls("databricks-datasets"))
